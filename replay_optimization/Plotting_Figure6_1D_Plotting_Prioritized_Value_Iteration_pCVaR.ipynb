# %% [markdown]
# # Imports

# %%
# Basics 
import numpy as np
import sys
import pickle
import os

# plotting 
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline 
from IPython.display import Image,display
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
import matplotlib.patches as patches

# Scipy 
import scipy 
import scipy.stats
from scipy.optimize import minimize
from scipy.stats import truncnorm
from scipy.optimize import linprog
from scipy.io import loadmat


sys.path.append('../plotting')
sys.path.append('../shared')

# %%
from plotting_basics import plot_q_or_pi,embellish_plot
from plotting_oneD import plot_1D_arrows
from matpy_conversions import convert_mat_s_to_python, convert_SI_function, convert_SIA_function
from scenarios import setup_params, Agent, state2idcs
from plotting_replays import plot_nested_replay, plot_xy_replay

# %% [markdown]
# # Loading Data

# %%
testcase=4
subcase='aS'

# %%
# Load CVaR Policy Eval on Random Code 
# It also has some stuff from the Value Iteration on the Same Case 
mat = loadmat('../simulation_results/1D_random_policy.mat')

# get MDP parameters 
Ny = mat['Y_set_all'].shape[1]
Ns = mat['Y_set_all'].shape[0] # could subtract one here 
Na = 3
gamma = mat['dis'][0][0]
y_set = mat['Y_set_all'][0,:]

# %%
p,maze = setup_params(testcase) 
agent = Agent({'num_states':Ns-1,
               'num_actions':Na,
               'start_states':[4],'r_params':p['r_params']},maze)

# %%
agent
example_name='1D'

# %% [markdown]
# # Figure 6

# %% [markdown]
# ## alpha=0.05

# %%
plot_xy_replay(example_name,
                agent,
                testcase = 4,
                subcase='aS',
                x_eval = 4,
                y_eval = 1,
                iters = 7,
                last_step=5,
                yis = [5,4,3,2,1,0], # should go in reverse
                savefolder='prioritized_replay_XY',
                save=False,
                remove_reward_color=False,
                title_alpha=0.05)
# Out:
# /kyb/agpd/cgagne/cvar_jmathpsych_2021/replay_optimization/../plotting/plotting_basics.py:430: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## alpha=0.1

# %%
plot_xy_replay(example_name,
                agent,
                testcase = 4,
                subcase='aS',
                x_eval = 4,
                y_eval = 2,
                iters = 7,
                last_step=5,
                yis = [5,4,3,2,1,0], # should go in reverse
                savefolder='prioritized_replay_XY',
                save=False,
                title_alpha=0.1)

# %% [markdown]
# ## alpha=0.3

# %%
plot_xy_replay(example_name,
                agent,
                testcase = 4,
                subcase='aS',
                x_eval = 4,
                y_eval = 3,
                iters = 7,
                last_step=5,
                yis = [5,4,3,2,1,0], # should go in reverse
                savefolder='prioritized_replay_XY',
                save=False,
                title_alpha=0.3)

# %% [markdown]
# ## alpha=0.6

# %%
plot_xy_replay(example_name,
                agent,
                testcase = 4,
                subcase='aS',
                x_eval = 4,
                y_eval = 4,
                iters = 7,
                last_step=5,
                yis = [5,4,3,2,1,0], # should go in reverse
                savefolder='prioritized_replay_XY',
                save=False,
                title_alpha=0.6)

# %% [markdown]
# ## alpha=1.0

# %%
plot_xy_replay(example_name,
                agent,
                testcase = 4,
                subcase='aS',
                x_eval = 4,
                y_eval = 5,
                iters = 7,
                last_step=5,
                yis = [5,4,3,2,1,0], # should go in reverse
                savefolder='prioritized_replay_XY',
                save=False,
                title_alpha=1)
